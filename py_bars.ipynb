# %%
# %matplotlib notebook

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
cities = ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]
bars_in_cities = [8.6, 8.5, 8.3, 7.9, 7.2]
# x_axis = np.arange(len(bars_in_cities))  # 0-4 (not shaun's way)

# %%
# Create a bar chart based upon the above data
plt.bar(cities, bars_in_cities, color='b', align="center")
# Out:
# <img src="data:image/png;base64,..." width="640">
# <BarContainer object of 5 artists>

# %%
# Create the ticks for our bar chart's x axis
# tick_locations = [value for value in x_axis] (not shaun's way)
# plt.xticks(tick_locations, ["New Orleans", "Milwaukee", "Omaha", "Pittsburgh", "Toledo"]) (not shaun's way)

# %%
# Set the limits of the x axis
# this is trial and error, there is no set limits for this
# New Orleans is still at 0, if limit below is 0 (not -.75) then half of NOLA is off the chart
plt.xlim(-0.75, len(x_axis)-0.25)
# Out:
# (-0.75, 4.75)

# %%
# Set the limits of the y axis
plt.ylim(0, max(bars_in_cities)+.2)
# Out:
# (0, 8.799999999999999)

# %%
# Give the chart a title, x label, and y label
plt.title("Density of Bars in Cities")
plt.xlabel("Cities")
plt.ylabel("Bars per 10,000 Households")
# Out:
# Text(69.77777777777779, 0.5, 'Bars per 10,000 Households')

# %%
# Save an image of the chart and print it to the screen
plt.savefig("../Images/BarDensity.png")
plt.show()
