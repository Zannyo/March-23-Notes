# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# usually want to use pandas when loading in csv files
# Load in csv
rain_df = pd.read_csv("../Resources/avg_rain_state.csv")
rain_df.head()
# Out:
#         State  Inches  Milli­metres  Rank
# 0     Alabama    58.3          1480     4
# 1      Alaska    22.5           572    39
# 2     Arizona    13.6           345    47
# 3    Arkansas    50.6          1284     8
# 4  California    22.2           563    40

# %%
# Set x axis and tick locations
x_axis = np.arange(len(rain_df))
tick_locations = [value+0.4 for value in x_axis]

# %%
# Create a list indicating where to write x labels and set figure size to adjust for space
plt.figure(figsize=(20,3))
plt.bar(x_axis, rain_df["Inches"], color='r', alpha=0.5, align="edge")
plt.xticks(tick_locations, rain_df["State"], rotation="vertical")
# Out:
# <img src="data:image/png;base64,..." width="2000">
# ([<matplotlib.axis.XTick at 0x252273d4148>,
#   <matplotlib.axis.XTick at 0x25227393988>,
#   <matplotlib.axis.XTick at 0x25227393b08>,
#   <matplotlib.axis.XTick at 0x25227499848>,
#   <matplotlib.axis.XTick at 0x2522749d188>,
#   <matplotlib.axis.XTick at 0x2522749d8c8>,
#   <matplotlib.axis.XTick at 0x252274a2248>,
#   <matplotlib.axis.XTick at 0x252274a2a48>,
#   <matplotlib.axis.XTick at 0x252274a6308>,
#   <matplotlib.axis.XTick at 0x252274a6b88>,
#   <matplotlib.axis.XTick at 0x252274ab408>,
#   <matplotlib.axis.XTick at 0x252274abc88>,
#   <matplotlib.axis.XTick at 0x252274af588>,
#   <matplotlib.axis.XTick at 0x252274ab8c8>,
#   <matplotlib.axis.XTick at 0x252274a22c8>,
#   <matplotlib.axis.XTick at 0x252274b4388>,
#   <matplotlib.axis.XTick at 0x252274b4e48>,
#   <matplotlib.axis.XTick at 0x252274b7748>,
#   <matplotlib.axis.XTick at 0x252274bb408>,
#   <matplotlib.axis.XTick at 0x252274be0c8>,
#   <matplotlib.axis.XTick at 0x252274beac8>,
#   <matplotlib.axis.XTick at 0x252274c3648>,
#   <matplotlib.axis.XTick at 0x252274c6248>,
#   <matplotlib.axis.XTick at 0x252274c3d08>,
#   <matplotlib.axis.XTick at 0x252274c60c8>,
#   <matplotlib.axis.XTick at 0x252274ca0c8>,
#   <matplotlib.axis.XTick at 0x252274caa88>,
#   <matplotlib.axis.XTick at 0x252274cd688>,
#   <matplotlib.axis.XTick at 0x252274d1248>,
#   <matplotlib.axis.XTick at 0x252274d1d08>,
#   <matplotlib.axis.XTick at 0x252274d5888>,
#   <matplotlib.axis.XTick at 0x252274d9408>,
#   <matplotlib.axis.XTick at 0x252274d9e08>,
#   <matplotlib.axis.XTick at 0x252274ca988>,
#   <matplotlib.axis.XTick at 0x252274dd448>,
#   <matplotlib.axis.XTick at 0x252274df188>,
#   <matplotlib.axis.XTick at 0x252274df808>,
#   <matplotlib.axis.XTick at 0x252274e44c8>,
#   <matplotlib.axis.XTick at 0x252274e80c8>,
#   <matplotlib.axis.XTick at 0x252274e8b88>,
#   <matplotlib.axis.XTick at 0x252274ec708>,
#   <matplotlib.axis.XTick at 0x252274f0048>,
#   <matplotlib.axis.XTick at 0x252274ece88>,
#   <matplotlib.axis.XTick at 0x252274d9e48>,
#   <matplotlib.axis.XTick at 0x252274f0f08>,
#   <matplotlib.axis.XTick at 0x252274f3708>,
#   <matplotlib.axis.XTick at 0x252274f6108>,
#   <matplotlib.axis.XTick at 0x252274f6ac8>,
#   <matplotlib.axis.XTick at 0x252274fa788>,
#   <matplotlib.axis.XTick at 0x252274fc308>],
#  <a list of 50 Text xticklabel objects>)

# %%
# Set x and y limits
plt.xlim(-0.25, len(x_axis))
plt.ylim(0, max(rain_df["Inches"])+10)
# Out:
# (0, 73.7)

# %%
# Set a Title and labels
plt.title("Average Rain per State")
plt.xlabel("State")
plt.ylabel("Average Amount of Rainfall in Inches")
# Out:
# Text(271.27777777777777, 0.5, 'Average Amount of Rainfall in Inches')

# %%
# Save our graph and show the grap
plt.tight_layout()
plt.savefig("../Images/avg_state_rain.png")
plt.show()
